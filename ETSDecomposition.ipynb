# %%
#To implement Error,trend and Seasonality Decomposition 
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
temp=pd.read_csv(r"C:\Users\Asus\Downloads\archive\Electric_Production.csv",index_col=0,parse_dates=True) #importing dataset and marking date field as index

temp.head()
# Out:
#             IPG2211A2N
# DATE
# 1985-01-01     72.5052
# 1985-02-01     70.6720
# 1985-03-01     62.4502
# 1985-04-01     57.4714
# 1985-05-01     55.3151

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result=seasonal_decompose(temp['IPG2211A2N'],model='multiplicative')
result.plot()
